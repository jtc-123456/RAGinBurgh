# %%
def build_file_name(url):
    return '-'.join(url.split("/")[2:]).replace('.','-') + ".json"

# %% [markdown]
# ## Wikipedia

# %%
import requests
from bs4 import BeautifulSoup
import json

def scrape_wikipedia_to_json(url, output_file):
    # Send request to the URL
    response = requests.get(url)
    
    # Parse the page content
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find the correct div based on the updated structure
    content = soup.find('div', {'id': 'mw-content-text'})

    # Dictionary to store the result
    data = {}
    current_h1 = None
    current_h2 = None
    current_h3 = None
    current_h4 = None
    current_h5 = None
    current_h6 = None

    # Iterate over headings and paragraphs
    for tag in content.find_all(['h2', 'h3', 'h4', 'h5', 'h6', 'p']):
        if tag.name == 'h2':
            current_h2 = tag.get_text(strip=True)
            data[current_h2] = {}
            current_h3 = current_h4 = current_h5 = current_h6 = None
        elif tag.name == 'h3' and current_h2:
            current_h3 = tag.get_text(strip=True)
            data[current_h2][current_h3] = {}
            current_h4 = current_h5 = current_h6 = None
        elif tag.name == 'h4' and current_h3:
            current_h4 = tag.get_text(strip=True)
            data[current_h2][current_h3][current_h4] = {}
            current_h5 = current_h6 = None
        elif tag.name == 'h5' and current_h4:
            current_h5 = tag.get_text(strip=True)
            data[current_h2][current_h3][current_h4][current_h5] = {}
            current_h6 = None
        elif tag.name == 'h6' and current_h5:
            current_h6 = tag.get_text(strip=True)
            data[current_h2][current_h3][current_h4][current_h5][current_h6] = {}
        elif tag.name == 'p':
            if current_h6:
                data[current_h2][current_h3][current_h4][current_h5][current_h6].setdefault('content', []).append(tag.get_text(strip=True))
            elif current_h5:
                data[current_h2][current_h3][current_h4][current_h5].setdefault('content', []).append(tag.get_text(strip=True))
            elif current_h4:
                data[current_h2][current_h3][current_h4].setdefault('content', []).append(tag.get_text(strip=True))
            elif current_h3:
                data[current_h2][current_h3].setdefault('content', []).append(tag.get_text(strip=True))
            elif current_h2:
                data[current_h2].setdefault('content', []).append(tag.get_text(strip=True))
    
    # Save the dictionary as a JSON file
    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=4)
    
    print(f"Content successfully written to {output_file}")

# %%
url_list = ["https://en.wikipedia.org/wiki/Pittsburgh", "https://en.wikipedia.org/wiki/History_of_Pittsburgh",
"https://en.wikipedia.org/wiki/Carnegie_Mellon_University"]
output_file_list = ["Pittsburgh_Wikipedia.json", "History_of_Pittsburgh_Wikipedia.json", "Carnegie_Mellon_University_Wikipedia.json"]
for url, output_file in zip(url_list, output_file_list):
    scrape_wikipedia_to_json(url, output_file)
# Out:
# Content successfully written to Pittsburgh_Wikipedia.json
# Content successfully written to History_of_Pittsburgh_Wikipedia.json
# Content successfully written to Carnegie_Mellon_University_Wikipedia.json

# %% [markdown]
# #### ---- scripts

# %%
type(content)
# Out:
# bs4.element.Tag

# %%
content = soup.find('div', {'id': 'bodyContent'})

# %%
content

# %%
for tag in content.find_all(['h1', 'h2', 'h3', 'h4', 'h5', 'h6', 'p']):
    print(tag.name)

# %%
# Dictionary to store the result
data = {}
current_h1 = None
current_h2 = None
current_h3 = None
current_h4 = None
current_h5 = None
current_h6 = None

# Iterate over headings and paragraphs
for tag in content.find_all(['h2', 'h3', 'h4', 'h5', 'h6', 'p']):
    if tag.name == 'h2':
        current_h2 = tag.get_text(strip=True)
        data[current_h2] = {}
        current_h3 = current_h4 = current_h5 = current_h6 = None
    elif tag.name == 'h3' and current_h2:
        current_h3 = tag.get_text(strip=True)
        data[current_h2][current_h3] = {}
        current_h4 = current_h5 = current_h6 = None
    elif tag.name == 'h4' and current_h3:
        current_h4 = tag.get_text(strip=True)
        data[current_h2][current_h3][current_h4] = {}
        current_h5 = current_h6 = None
    elif tag.name == 'h5' and current_h4:
        current_h5 = tag.get_text(strip=True)
        data[current_h2][current_h3][current_h4][current_h5] = {}
        current_h6 = None
    elif tag.name == 'h6' and current_h5:
        current_h6 = tag.get_text(strip=True)
        data[current_h2][current_h3][current_h4][current_h5][current_h6] = {}
    elif tag.name == 'p':
        if current_h6:
            data[current_h2][current_h3][current_h4][current_h5][current_h6].setdefault('content', []).append(tag.get_text(strip=True))
        elif current_h5:
            data[current_h2][current_h3][current_h4][current_h5].setdefault('content', []).append(tag.get_text(strip=True))
        elif current_h4:
            data[current_h2][current_h3][current_h4].setdefault('content', []).append(tag.get_text(strip=True))
        elif current_h3:
            data[current_h2][current_h3].setdefault('content', []).append(tag.get_text(strip=True))
        elif current_h2:
            data[current_h2].setdefault('content', []).append(tag.get_text(strip=True))

# %%
data

# %% [markdown]
# ### pittsburghpa.gov

# %%
import requests
from bs4 import BeautifulSoup

def get_subpage_links(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find all <a> tags
    links = []
    for a_tag in soup.find_all('a', href=True):
        link = a_tag['href']
        if link.startswith('/'):  # If it's a relative link, prepend the base URL
            link = f"{url.rstrip('/')}{link}"
        links.append(link)
    
    return links

# Example usage
url = "https://pittsburghpa.gov/index.html"  # Replace with the base URL
subpage_links = get_subpage_links(url)
print(f"Found {len(subpage_links)} subpage links:")
for link in subpage_links:
    print(link)
# Out:
# Found 346 subpage links:
# #
# #
# ../index.html
# https://www.votespa.com/Pages/default.aspx
# https://pittsburghpa.gov/guia-para-residentes-de-la-ciudad-de-pittsburgh/introduccion
# https://pittsburghpa.gov/311
# https://pittsburghpa.gov/mayor/covid-updates
# https://pittsburghpa.gov/dcp/ccb-ada
# https://pittsburghpa.gov/city-info/frequent-numbers
# https://pittsburghpa.gov/city-info/socialmedia
# page.html
# https://pittsburghpa.gov/311
# https://pittsburghpa.gov/citiparks/parks.html
# https://cprbpgh.org/
# https://pittsburghpa.gov/dcp/index.html
# https://pittsburghpa.gov/chr/index.html
# https://engage.pittsburghpa.gov/
# https://pittsburghpa.gov/ehb/index.html
# https://pittsburghpa.gov/finance/finance.html
# https://pittsburghpa.gov/innovation-performance/index.html
# https://pittsburghpa.gov/humanresources/index.html
# https://www.governmentjobs.com/careers/pittsburgh
# https://pittsburghpa.gov/domi/index.html
# https://pittsburghpa.gov/ochs/index.html
# https://pittsburghpa.gov/publicsafety/ofem
# https://pittsburghpa.gov/pli/index.html
# https://pittsburghpa.gov/publicsafety/index.html
# https://pittsburghpa.gov/dpw/dpw.html
# https://pittsburghpa.gov/schenley/rink
# https://pittsburghpa.gov/events/index.html
# https://pittsburghpa.shinyapps.io/BurghsEyeView/
# https://pittsburghpa.gov/weather/index.html
# page.html
# https://pittsburghpa.gov/citiparks/parks.html
# https://engage.pittsburghpa.gov/
# https://pittsburghpa.gov/pittsburgh/pgh-about
# https://encrypted.google.com/url?sa=t&rct=j&q=&esrc=s&source=web&cd=1&cad=rja&uact=8&ved=0ahUKEwiJlq-ft7DTAhWELyYKHS4XBT0QFggkMAA&url=http%3A%2F%2Fwww.nextpittsburgh.com%2F&usg=AFQjCNEdojBqqVd0mmLIdQ-7tzXDUSNojA&sig2=OtFTa_G9y3GOVAzL89IXqA
# https://pittsburghpa.gov/publicsafety/ofem
# https://pittsburghpa.gov/schenley/rink
# https://pittsburghpa.gov/events/index.html
# https://visitpittsburgh.com
# https://pittsburghpa.gov/mayor/welcoming-pgh/index.html
# page.html
# https://pittsburghpa.gov/beacon/index.html
# https://pittsburghpa.gov/dcp/index.html
# https://pittsburghpa.gov/finance/finance.html
# https://pittsburghpa.gov/innovation-performance/index.html
# https://pittsburghpa.gov/clerk/lic
# https://pittsburghpa.gov/domi/index.html
# https://pittsburghpa.gov/innovation-performance/pghlab/index.html
# https://pittsburghpa.gov/pli/index.html
# page.html
# https://pittsburghpa.gov/index.html/bac/bac.html
# https://pittsburghpa.gov/clerk/index.html
# https://pittsburghpa.gov/council/index.html
# https://pittsburghpa.gov/clerk/council-meetings
# https://pittsburghpa.gov/omb/omb.html
# https://pittsburghpa.gov/cmptf/index.html
# https://pittsburghpa.gov/controller/controller.html
# https://pittsburghpa.gov/humanresources/index.html
# https://pittsburghpa.gov/law/index.html
# https://pittsburghpa.gov/mayor/city-staff
# https://pittsburghpa.gov/mayor/index.html
# https://pittsburghpa.gov/pension/index.html
# https://pittsburghpa.gov/omb/omb.html
# https://pittsburghpa.gov/omi/index.html
# https://pittsburghpa.gov/finance/opeb
# https://pittsburghpa.gov/publicsafety/index.html
# https://www.pittsburghpa.gov/city-county-100/index.html
# page.html
# https://onestoppgh.pittsburghpa.gov/pghprod/pub/lms/Login.aspx
# https://pittsburghpa.gov/beacon/index.html
# https://pittsburghpa.civiccentral.com/
# https://pittsburghpa.shinyapps.io/BurghsEyeView/
# https://pittsburghpa.gov/dashburgh/index.html
# https://engage.pittsburghpa.gov
# https://pittsburghpa.gov/park-shelter/reserve
# https://fiscalfocus.pittsburghpa.gov/
# https://pittsburghpa.gov/finance/finance-permits-licenses
# https://www.openbookpittsburgh.com/
# https://www.dspayments.com/Pittsburgh
# https://www.gomobilepittsburgh.com/
# https://ww2.payerexpress.com/ebp/ppapleases/
# https://magic.collectorsolutions.com/magic-ui/Login/pittsburgh
# https://pittsburghpa.gov/snowangels/index.html
# https://pittsburghpa.gov/weather/snow-plow-tracker
# https://pittsburghpa.gov/publicsafety/ofem
# https://pgh.st/
# page.html
# https://pittsburghpa.gov/pittsburgh/pgh-about
# https://pittsburghpa.gov/city-info/frequent-numbers
# https://pittsburghpa.gov/city-info/policies
# https://pittsburghpa.gov/city-info/press-releases
# https://pittsburghpa.gov/publicsafety/blotterview.html
# https://pittsburghpa.gov/dpw/collection-schedule
# https://pittsburghpa.gov/finance/tax-forms
# https://pittsburghpa.gov/clerk/council-meetings
# https://pittsburghpa.gov/city-info/release-notes
# https://www.governmentjobs.com/careers/pittsburgh
# https://pittsburghpa.gov/womens-suffrage/index.html
# https://www.governmentjobs.com/careers/pittsburgh/transferjobs
# https://pittsburghpa.gov/city-info/city-events
# https://pittsburghpa.gov/index.html/index.html
# https://pittsburghpa.gov/index.html/index.html
# https://pittsburghpa.gov/311
# https://pittsburghpa.gov/mayor/covid-updates
# https://www.governmentjobs.com/careers/pittsburgh
# https://pittsburghpa.gov/city-info/frequent-numbers
# https://pittsburghpa.gov/city-info/socialmedia
# https://pittsburghpa.gov/guia-para-residentes-de-la-ciudad-de-pittsburgh/introduccion
# #
# https://pittsburghpa.gov/311
# https://pittsburghpa.gov/citiparks/parks.html
# https://cprbpgh.org/
# https://pittsburghpa.gov/dcp/index.html
# https://pittsburghpa.gov/chr/index.html
# https://pittsburghpa.gov/ehb/index.html
# https://engage.pittsburghpa.gov/
# https://pittsburghpa.gov/finance/finance.html
# https://pittsburghpa.gov/innovation-performance/index.html
# https://pittsburghpa.gov/humanresources/index.html
# https://www.governmentjobs.com/careers/pittsburgh
# https://pittsburghpa.gov/domi/index.html
# https://pittsburghpa.gov/ochs/index.html
# https://pittsburghpa.gov/publicsafety/ofem
# https://pittsburghpa.gov/events/index.html
# https://pittsburghpa.gov/pli/index.html
# https://pittsburghpa.gov/publicsafety/index.html
# https://pittsburghpa.gov/dpw/index.html
# https://pittsburghpa.gov/schenley/rink
# https://pittsburghpa.gov/events/index.html
# https://pittsburghpa.shinyapps.io/BurghsEyeView/
# https://pittsburghpa.gov/weather/index.html
# #
# https://pittsburghpa.gov/citiparks/parks.html
# https://engage.pittsburghpa.gov/
# https://pittsburghpa.gov/pittsburgh/pgh-about
# https://pittsburghpa.gov/publicsafety/ofem
# https://pittsburghpa.gov/schenley/rink
# https://pittsburghpa.gov/events/index.html
# https://visitpittsburgh.com
# https://pittsburghpa.gov/mayor/welcoming-pgh/index.html
# #
# https://pittsburghpa.gov/beacon/index.html
# https://pittsburghpa.gov/dcp/index.html
# https://pittsburghpa.gov/finance/finance.html
# https://pittsburghpa.gov/innovation-performance/index.html
# https://pittsburghpa.gov/clerk/lic
# https://pittsburghpa.gov/domi/index.html
# https://pittsburghpa.gov/innovation-performance/pghlab/index.html
# https://pittsburghpa.gov/pli/index.html
# #
# https://pittsburghpa.gov/index.html/bac/bac.html
# https://pittsburghpa.gov/clerk/index.html
# https://pittsburghpa.gov/council/index.html
# https://pittsburghpa.gov/clerk/council-meetings
# https://pittsburghpa.gov/omb/community-development-block-grant
# https://pittsburghpa.gov/cmptf/index.html
# https://pittsburghpa.gov/controller/index.html
# https://pittsburghpa.gov/humanresources/index.html
# https://pittsburghpa.gov/law/index.html
# https://pittsburghpa.gov/mayor/city-staff
# https://pittsburghpa.gov/mayor/index.html
# https://pittsburghpa.gov/pension/index.html
# https://pittsburghpa.gov/omb/omb.html
# https://pittsburghpa.gov/omi/index.html
# https://pittsburghpa.gov/finance/opeb
# https://pittsburghpa.gov/publicsafety/index.html
# https://pittsburghpa.gov/city-county-100/index.html
# #
# https://pittsburghpa.gov/beacon/index.html
# https://pittsburghpa.civiccentral.com/
# https://pittsburghpa.shinyapps.io/BurghsEyeView/
# https://engage.pittsburghpa.gov
# https://pittsburghpa.gov/park-shelter/reserve
# https://fiscalfocus.pittsburghpa.gov/
# https://pittsburghpa.gov/finance/finance-permits-licenses
# https://onestoppgh.pittsburghpa.gov/pghprod/pub/lms/Login.aspx
# https://www.openbookpittsburgh.com/
# https://www.dspayments.com/Pittsburgh
# https://www.gomobilepittsburgh.com/
# https://ww2.payerexpress.com/ebp/ppapleases/
# https://magic.collectorsolutions.com/magic-ui/Login/pittsburgh
# https://pittsburghpa.gov/controller/watchdog
# https://pgh.st/
# https://pittsburghpa.gov/snowangels/index.html
# https://pittsburghpa.gov/weather/snow-plow-tracker
# https://pittsburghpa.gov/publicsafety/ofem
# #
# https://pittsburghpa.gov/pittsburgh/pgh-about
# https://pittsburghpa.gov/city-info/frequent-numbers
# https://pittsburghpa.gov/city-info/policies
# https://pittsburghpa.gov/city-info/press-releases
# https://pittsburghpa.gov/publicsafety/blotterview.html
# https://pittsburghpa.gov/dpw/collection-schedule
# https://pittsburghpa.gov/finance/tax-forms
# https://pittsburghpa.gov/clerk/council-meetings
# https://pittsburghpa.gov/city-info/release-notes
# https://www.governmentjobs.com/careers/pittsburgh
# https://www.governmentjobs.com/careers/pittsburgh/transferjobs
# httpss://www.google.com/maps/place/Pittsburgh,+PA/data=!4m2!3m1!1s0x8834f16f48068503:0x8df915a15aa21b34?ved=2ahUKEwjW-r6fis3gAhXvRd8KHau2Bk0Q8gEwAHoECAAQAQ
# #
# https://pittsburghpa.gov/index.html/omb/budgets-reports/index.html
# https://www.governmentjobs.com/careers/pittsburgh
# https://pittsburghpa.shinyapps.io/BurghsEyeView/
# https://www.wprdc.org/
# https://www.pittsburghparking.com/
# https://pittsburghpa.gov/domi/paving-schedule
# https://goo.gl/ZPbkRa
# https://pittsburghpa.gov/dpw/collection-schedule
# https://pittsburghpa.gov/events/index.html
# https://pittsburghpa.gov/finance/tax-descriptions
# https://pittsburghpa.gov/dcp/zoning
# #
# https://pittsburghpa.gov/311
# https://www.cityalarmpermit.com/FAMS/Citizen/City/Pittsburgh/ATB_Login.aspx
# https://apps.pittsburghpa.gov/finance/Business_Discontinuation_Form_2015.pdf
# https://pittsburghpa.gov/pli/commercial-building-permit
# https://pittsburghpa.gov/publicsafety/dog-license
# https://pittsburghpa.gov/events/permitting
# https://pittsburghpa.gov/pli/building-permit
# https://pittsburghpa.gov/domi/right-of-way
# https://pittsburghpa.gov/pli/pli-business-licenses
# #
# https://www.cityalarmpermit.com/FAMS/Citizen/City/Pittsburgh/ATB_Login.aspx
# https://registerparks.pittsburghpa.gov/
# https://ww2.payerexpress.com/ebp/ppapleases/
# https://www.dspayments.com/pittsburgh
# https://www.pgh2o.com/pay
# https://magic.collectorsolutions.com/magic-ui/Login/pittsburgh
# https://content.govdelivery.com/bulletins/gd/PAPITT-3bab75c?wgt_ref=PAPITT_WIDGET_4
# https://content.govdelivery.com/bulletins/gd/PAPITT-3ba1762?wgt_ref=PAPITT_WIDGET_4
# https://content.govdelivery.com/bulletins/gd/PAPITT-3b99c2e?wgt_ref=PAPITT_WIDGET_4
# https://pittsburghpa.gov/inc/announcement.html?ta=mayor
# #
# https://pittsburghpa.gov/omb/budgets-reports
# https://www.governmentjobs.com/careers/pittsburgh
# https://ecsr.net/
# https://pittsburghpa.shinyapps.io/BurghsEyeView/
# https://www.wprdc.org/
# https://www.pittsburghparking.com/
# https://pittsburghpa.gov/domi/paving-schedule
# https://goo.gl/ZPbkRa
# https://pittsburghpa.gov/dpw/collection-schedule
# https://pittsburghpa.gov/events/index.html
# https://pittsburghpa.gov/finance/tax-descriptions
# https://pittsburghpa.gov/dcp/zoning
# #
# https://pittsburghpa.gov/311/
# https://onestoppgh.pittsburghpa.gov/pghprod/pub/lms/Login.aspx
# https://apps.pittsburghpa.gov/finance/Business_Discontinuation_Form_2015.pdf
# https://pittsburghpa.gov/pli/commercial-building-permit
# https://www.dmv.org/pa-pennsylvania/disabled-drivers.php
# https://pittsburghpa.gov/publicsafety/dog-license
# https://pittsburghpa.gov/events/permitting
# https://pittsburghpa.gov/pli/building-permit
# https://pittsburghpa.gov/domi/right-of-way
# https://pittsburghpa.gov/pli/pli-business-licenses
# #
# https://www.cityalarmpermit.com/FAMS/Citizen/City/Pittsburgh/ATB_Login.aspx
# https://pittsburghpa.gov/park-shelter/reserve
# https://ww2.payerexpress.com/ebp/ppapleases/
# https://www.dspayments.com/pittsburgh
# https://www.pgh2o.com/pay
# https://magic.collectorsolutions.com/magic-ui/Login/pittsburgh
# https://content.govdelivery.com/bulletins/gd/PAPITT-3bab75c?wgt_ref=PAPITT_WIDGET_4
# https://content.govdelivery.com/bulletins/gd/PAPITT-3ba1762?wgt_ref=PAPITT_WIDGET_4
# https://content.govdelivery.com/bulletins/gd/PAPITT-3b99c2e?wgt_ref=PAPITT_WIDGET_4
# https://pittsburghpa.gov/inc/announcement.html?ta=mayor
# https://pittsburghpa.gov/dpw/curbside-pick-up
# https://pittsburghpa.gov/council/index.html
# https://pittsburghpa.gov/events/index.html
# https://pittsburghpa.gov/citiparks/index.html
# https://pittsburghpa.gov/311/
# http://www.pittsburghparking.com/
# https://pittsburghpa.gov/publicsafety/index.html
# https://pittsburghpa.gov/publicsafety/dog-license
# https://pittsburghpa.gov/publicsafety/animal-control
# https://pittsburghpa.gov/innovation-performance/gis
# https://www.pps.k12.pa.us/
# https://pittsburghpa.gov/city-info/press-releases.html
# https://pittsburghpa.gov/park-shelter/reserve
# https://pittsburghpa.gov/finance/finance.html
# https://pittsburghpa.shinyapps.io/BurghsEyeView/
# https://pittsburghpa.gov/beacon/index.html
# https://pittsburghpa.gov/clerk/lic
# https://www.portauthority.org/
# https://pittsburghpa.gov/dpw/dpw.html
# https://pittsburghpa.gov/pli/index.html
# https://pittsburghpa.gov/index.html/bac/bac.html
# https://pittsburghpa.gov/bpm/black-pittsburgh-matters
# https://pittsburghpa.gov/city-info/frequent-numbers
# https://pittsburghpa.gov/city-info/press-releases
# http://apps.pittsburghpa.gov/redtail/images/21524_COP_Buying_Plan_2023.pdf
# https://pittsburghpa.gov/beacon/bid-opportunities-opengov.html
# https://www.openbookpittsburgh.com/SearchContracts.aspx
# https://pittsburghpa.gov/mayor/city-staff
# https://pittsburghpa.gov/clerk/council-meetings
# https://pittsburghpa.gov/controller/expenditure-report
# https://pittsburghpa.gov/finance/index.html
# https://pittsburghpa.gov/finance/new-bus-reg
# https://pittsburghpa.gov/clerk/lic
# https://library.municode.com/pa/pittsburgh/codes/code_of_ordinances
# https://pittsburghpa.gov/clerk/home-rule-charter
# https://pittsburghpa.gov/omb/budgets-reports
# https://www.openbookpittsburgh.com/
# https://pittsburghpa.gov/law/right-to-know
# https://pittsburghpa.gov/innovation-performance/pghlab/index.html
# https://pittsburghpa.gov/controller/pafr
# https://pittsburghpa.gov/controller/annualreport
# https://fiscalfocus.pittsburghpa.gov/
# https://pittsburghpa.buildingeye.com/building
# https://pittsburghpa.gov/police/data-portal
# https://www.wprdc.org/
# https://pittsburghpa.gov/controller/fiscal-audits
# https://pittsburghpa.gov/omb/budget-tax-receipt-simulation
# https://pittsburghpa.gov/beacon/index.html
# https://pittsburghpa.gov/harp/
# https://pittsburghpa.shinyapps.io/BurghsEyeView/
# https://itunes.apple.com/us/app/myburgh/id1021606996?mt=8
# https://play.google.com/store/apps/details?id=com.qscend.report2gov.myburgh&hl=en
# https://pittsburghpa.gov/city-info/frequent-numbers
# https://pittsburghpa.gov/city-info/open-gov
# https://pittsburghpa.gov/city-info/policies
# https://pittsburghpa.gov/city-info/press-releases
# https://pittsburghpa.gov/city-info/release-notes.html
# https://pittsburghpa.gov/dcp/web-accessibility-short
# https://pittsburghpa.gov/311/
# https://pittsburghpa.gov/beacon/index.html
# https://pittsburghpa.gov/publicsafety/dog-license
# https://pittsburghpa.gov/park-shelter/reserve
# https://pittsburghpa.gov/finance/finance.html
# https://onestoppgh.pittsburghpa.gov/pghprod/pub/lms/Login.aspx
# https://pittsburghpa.gov/bac/bac.html
# https://pittsburghpa.gov/clerk/index.html
# https://pittsburghpa.gov/council/index.html
# https://pittsburghpa.gov/controller/controller.html
# https://pittsburghpa.gov/mayor/index.html
# https://pittsburghpa.gov/publicsafety/index.html
# https://www.facebook.com/city.of.pittsburgh/
# https://twitter.com/Pittsburgh
# https://youtube.com/channel/UC-YfIv9wvBjGT3LMxo9hLoQ
# https://pittsburghpa.gov/city-info/socialmedia
# https://pittsburghpa.gov
# #modal-close
# https://getinvolved.pittsburghpa.gov/city-website-redesign

# %%
# https://pittsburghpa.gov/pittsburgh/pgh-about
gov_urls = ["https://pittsburghpa.gov/pittsburgh/pgh-about", "https://pittsburghpa.gov/pittsburgh/pgh-sports", 
"https://pittsburghpa.gov/pittsburgh/cultural-activities", "https://pittsburghpa.gov/pittsburgh/flag-seal", 
"https://pittsburghpa.gov/mayor/pghmayors"]


gov_files = []
for url in gov_urls:
    gov_files.append(build_file_name(url))

for url, output_file in zip(gov_urls, gov_files):
    scrape_gov_to_json(url, output_file)
# Out:
# pittsburghpa-gov-pittsburgh-pgh-about.json
# pittsburghpa-gov-pittsburgh-pgh-sports.json
# pittsburghpa-gov-pittsburgh-cultural-activities.json
# pittsburghpa-gov-pittsburgh-flag-seal.json
# pittsburghpa-gov-mayor-pghmayors.json

# %%
def scrape_gov_to_json(url, output_file):
    # Send request to the URL
    response = requests.get(url)
    
    # Parse the page content
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find the correct div based on the updated structure
    content = soup.find('div', {'class': 'col-md-12'})

    # Dictionary to store the result
    data = {}
    for passage in content.find_all('p'):
        data.setdefault('content', []).append(passage.get_text(strip=True))
    
    # Save the dictionary as a JSON file
    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=4)
    
    print(f"Content successfully written to {output_file}")
# Out:
# Content successfully written to Pittsburgh_Gov_About.json
# Content successfully written to Pittsburgh_Gov_Sports.json
